# %% [markdown]
# Unicorn EDA

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.rcParams['figure.figsize'] = [12,6]
plt.rcParams['figure.dpi'] = 70
sns.set_theme(style='white')
sns.set_palette(palette='Spectral')

# %%
unicorn = pd.read_csv('Unicorn_Clean.csv')

# %%
unicorn.head()
# Out:
#    Unnamed: 0    Company  Valuation ($B) Date Joined        Country  \
# 0           0  Bytedance           140.0  2017-04-07          China
# 1           1     SpaceX           100.3  2012-12-01  United States
# 2           2     Stripe            95.0  2014-01-23  United States
# 3           3     Klarna            45.6  2011-12-12         Sweden
# 4           4      Canva            40.0  2018-01-08      Australia
#
#             City                      Industry  \
# 0        Beijing       Artificial intelligence
# 1      Hawthorne                         Other
# 2  San Francisco                       Fintech
# 3      Stockholm                       Fintech
# 4    Surry Hills  Internet software & services
#
#                        Investor 1               Investor 2  \
# 0           Sequoia Capital China     SIG Asia Investments
# 1                   Founders Fund  Draper Fisher Jurvetson
# 2                 Khosla Ventures         LowercaseCapital
# 3  Institutional Venture Partners          Sequoia Capital
# 4           Sequoia Capital China       Blackbird Ventures
#
#             Investor 3      Investor 4
# 0           Sina Weibo  Softbank Group
# 1  Rothenberg Ventures             NaN
# 2             capitalG             NaN
# 3     General Atlantic             NaN
# 4      Matrix Partners             NaN

# %%
unicorn.drop(columns='Unnamed: 0', inplace=True)

# %%
unicorn['Date Joined'] = pd.to_datetime(unicorn['Date Joined'])

# %%
unicorn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         936 non-null    object
#  1   Valuation ($B)  936 non-null    float64
#  2   Date Joined     936 non-null    datetime64[ns]
#  3   Country         936 non-null    object
#  4   City            936 non-null    object
#  5   Industry        936 non-null    object
#  6   Investor 1      936 non-null    object
#  7   Investor 2      890 non-null    object
#  8   Investor 3      806 non-null    object
#  9   Investor 4      7 non-null      object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 73.2+ KB

# %% [markdown]
# Qustions:
# - What company are the most valuable?
# - What industry are the most valuable?
# - What is the segmentation of industry?
# - What country produces the most unicorns?
# - Which unicorn had the steepest rise?
# - Which investors are most succeful?

# %% [markdown]
# Most Valuable Company

# %%
value_top20 = unicorn.sort_values(by='Valuation ($B)', ascending=False).head(20) #top 20 most valuable unicorns

# %%
g = sns.barplot(data=value_top20, x = 'Company', y = 'Valuation ($B)', hue = 'Industry', dodge= False, palette = 'Spectral')
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# Most Valuable Industry

# %%
industry_value = unicorn.groupby(by='Industry').sum().sort_values(by='Valuation ($B)', ascending=False)

# %%
industry_value
# Out:
#                                    Valuation ($B)
# Industry
# Fintech                                    744.13
# Internet software & services               483.76
# Artificial intelligence                    312.84
# E-commerce & direct-to-consumer            291.10
# Other                                      245.46
# Health                                     166.26
# Supply chain logistics & delivery          146.29
# Data management & analytics                121.70
# Cybersecurity                              107.54
# Hardware                                    98.59
# Auto & transportation                       89.30
# Edtech                                      85.37
# Mobile & telecommunications                 79.09
# Consumer & retail                           64.13
# Travel                                      35.60

# %%
g = sns.barplot(data=industry_value, x = industry_value.index, y = 'Valuation ($B)', palette = 'Spectral')
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# Segmentation of Market

# %%
industry_value_per = industry_value['Valuation ($B)'].apply(lambda x: (x/ industry_value.sum()) * 100).round(2)

# %%
g = sns.barplot(data=industry_value_per, x = industry_value_per.index, y = 'Valuation ($B)', palette = 'Spectral')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set_ylabel('Value as share of Market (%)');

# %% [markdown]
# Close to 25% of the total market value is in Fintech. The top 3 biggest industries make up more than 50% of total market value ($1540 Billion)

# %%
industry_value_per.iloc[:3].sum()
# Out:
# Valuation ($B)    50.17
# dtype: float64

# %%
industry_value.iloc[:3].sum()
# Out:
# Valuation ($B)    1540.73
# dtype: float64

# %% [markdown]
# Unicorns per Country

# %%
country_value = unicorn.groupby(by='Country').sum().sort_values(by='Valuation ($B)', ascending=False).head(20)

# %%
g = sns.barplot(data=country_value, x = country_value.index, y = 'Valuation ($B)', palette = 'Spectral')
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %%
country_sorted = unicorn['Country'].value_counts().rename_axis('Country').reset_index(name='counts')

# %%
country_sorted.head(20)
# Out:
#            Country  counts
# 0    United States     478
# 1            China     169
# 2            India      51
# 3   United Kingdom      37
# 4          Germany      23
# 5           Israel      21
# 6           France      19
# 7           Brazil      15
# 8           Canada      15
# 9        Singapore      11
# 10     South Korea      11
# 11       Hong Kong       7
# 12       Australia       6
# 13           Japan       6
# 14          Mexico       5
# 15     Netherlands       5
# 16       Indonesia       5
# 17           Spain       4
# 18          Sweden       4
# 19     Switzerland       4

# %%
country_sorted_per = country_sorted['counts'].apply(lambda x: (x/ country_sorted.counts.sum()) * 100).round(2)

# %%
country_sorted_per.head(20) #percentage of total amount of unicorns per country - top 20
# Out:
# 0     51.07
# 1     18.06
# 2      5.45
# 3      3.95
# 4      2.46
# 5      2.24
# 6      2.03
# 7      1.60
# 8      1.60
# 9      1.18
# 10     1.18
# 11     0.75
# 12     0.64
# 13     0.64
# 14     0.53
# 15     0.53
# 16     0.53
# 17     0.43
# 18     0.43
# 19     0.43
# Name: counts, dtype: float64

# %%
g = sns.barplot(data=country_sorted[:20], x = 'Country', y = 'counts', palette = 'Spectral')
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# We see that the vast majority of unicorns reside in the US (51%).

# %%
sns.histplot(data=unicorn, x = 'Date Joined');

# %% [markdown]
# Clearly, 2021 was the year of the unicorn. I'm curious which companies started earliest.

# %%
unicorn.sort_values(by='Date Joined').head(10) #10 oldest unicorns (still private)
# Out:
#                         Company  Valuation ($B) Date Joined        Country  \
# 557                      Veepee            1.38  2007-07-20         France
# 224                       VANCL            3.00  2010-12-14          China
# 99                   Vice Media            5.70  2011-04-02  United States
# 3                        Klarna           45.60  2011-12-12         Sweden
# 349  Trendy Group International            2.00  2012-02-13      Hong Kong
# 15                     Fanatics           18.00  2012-06-06  United States
# 1                        SpaceX          100.30  2012-12-01  United States
# 350                       Avant            2.00  2012-12-17  United States
# 482                    Mu Sigma            1.50  2013-02-07  United States
# 423                  Automattic            1.80  2013-05-27  United States
#
#                       City                         Industry  \
# 557  La Plaine Saint-Denis  E-commerce & direct-to-consumer
# 224                Beijing  E-commerce & direct-to-consumer
# 99                Brooklyn     Internet software & services
# 3                Stockholm                          Fintech
# 349                Kowloon                Consumer & retail
# 15            Jacksonville  E-commerce & direct-to-consumer
# 1                Hawthorne                            Other
# 350                Chicago          Artificial intelligence
# 482             Northbrook      Data management & analytics
# 423          San Francisco     Internet software & services
#
#                          Investor 1               Investor 2  \
# 557                 Summit Partners            Qatar Holding
# 224                 Ceyuan Ventures  QiMing Venture Partners
# 99    Technology Crossover Ventures  A&E Television Networks
# 3    Institutional Venture Partners          Sequoia Capital
# 349              L Capital Partners                      NaN
# 15                   SoftBank Group      Andreessen Horowitz
# 1                     Founders Fund  Draper Fisher Jurvetson
# 350                    RRE Ventures             Tiger Global
# 482                 Sequoia Capital         General Atlantic
# 423        Insight Venture Partners        Lowercase Capital
#
#               Investor 3 Investor 4
# 557                  NaN        NaN
# 224     Temasek Holdings        NaN
# 99                   NaN        NaN
# 3       General Atlantic        NaN
# 349                  NaN        NaN
# 15      Temasek Holdings        NaN
# 1    Rothenberg Ventures        NaN
# 350       August Capital        NaN
# 482                  NaN        NaN
# 423     Polaris Partners        NaN

# %%
unicorn_2015 = unicorn[unicorn['Date Joined'] > '2014']

# %%
sns.histplot(data=unicorn_2015, x = 'Date Joined', hue = 'Industry', palette = 'Spectral',bins=40);

# %%
g = sns.displot(data=unicorn_2015, x = 'Date Joined', hue = 'Industry', palette = 'Spectral', legend=False, height=20, col='Industry', col_wrap=3)
sns.despine(fig=None, ax=None, top=True, right=True, left=True, bottom=True, offset=None, trim=True)
g.set_titles(size=50, pad=-300);

# %% [markdown]
# We see the astronomical rise in value of especially Fintech and Internet software & services in the last 5 years.

# %%
# rise degree as value of time
unicorn
# Out:
#              Company  Valuation ($B) Date Joined        Country  \
# 0          Bytedance           140.0  2017-04-07          China
# 1             SpaceX           100.3  2012-12-01  United States
# 2             Stripe            95.0  2014-01-23  United States
# 3             Klarna            45.6  2011-12-12         Sweden
# 4              Canva            40.0  2018-01-08      Australia
# ..               ...             ...         ...            ...
# 931        YipitData             1.0  2021-12-06  United States
# 932         Anyscale             1.0  2021-12-07  United States
# 933  Iodine Software             1.0  2021-12-01  United States
# 934       ReliaQuest             1.0  2021-12-01  United States
# 935       Pet Circle             1.0  2021-12-07      Australia
#
#               City                         Industry  \
# 0          Beijing          Artificial intelligence
# 1        Hawthorne                            Other
# 2    San Francisco                          Fintech
# 3        Stockholm                          Fintech
# 4      Surry Hills     Internet software & services
# ..             ...                              ...
# 931       New York     Internet software & services
# 932       Berkeley          Artificial intelligence
# 933         Austin      Data management & analytics
# 934          Tampa                    Cybersecurity
# 935     Alexandria  E-commerce & direct-to-consumer
#
#                          Investor 1                 Investor 2  \
# 0             Sequoia Capital China       SIG Asia Investments
# 1                     Founders Fund    Draper Fisher Jurvetson
# 2                   Khosla Ventures           LowercaseCapital
# 3    Institutional Venture Partners            Sequoia Capital
# 4             Sequoia Capital China         Blackbird Ventures
# ..                              ...                        ...
# 931                   RRE Ventures+  Highland Capital Partners
# 932             Andreessen Horowitz              Intel Capital
# 933            Advent International      Bain Capital Ventures
# 934                             KKR                FTV Capital
# 935                   Prysm Capital      Baillie Gifford & Co.
#
#                        Investor 3      Investor 4
# 0                      Sina Weibo  Softbank Group
# 1             Rothenberg Ventures             NaN
# 2                        capitalG             NaN
# 3                General Atlantic             NaN
# 4                 Matrix Partners             NaN
# ..                            ...             ...
# 931             The Carlyle Group             NaN
# 932            Foundation Capital             NaN
# 933  Silversmith Capital Partners             NaN
# 934           Ten Eleven Ventures             NaN
# 935           TDM Growth Partners             NaN
#
# [936 rows x 10 columns]

# %% [markdown]
# Creating time delta column of days since inception as Age

# %%
unicorn['Age'] = (datetime.now() - unicorn['Date Joined']).apply(lambda x: x.days)

# %%
unicorn['Daily Value ($M)'] = (unicorn['Valuation ($B)'] / unicorn['Age']) * 1000

# %%
unicorn.head()
# Out:
#      Company  Valuation ($B) Date Joined        Country           City  \
# 0  Bytedance           140.0  2017-04-07          China        Beijing
# 1     SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2     Stripe            95.0  2014-01-23  United States  San Francisco
# 3     Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4      Canva            40.0  2018-01-08      Australia    Surry Hills
#
#                        Industry                      Investor 1  \
# 0       Artificial intelligence           Sequoia Capital China
# 1                         Other                   Founders Fund
# 2                       Fintech                 Khosla Ventures
# 3                       Fintech  Institutional Venture Partners
# 4  Internet software & services           Sequoia Capital China
#
#                 Investor 2           Investor 3      Investor 4   Age  \
# 0     SIG Asia Investments           Sina Weibo  Softbank Group  1710
# 1  Draper Fisher Jurvetson  Rothenberg Ventures             NaN  3298
# 2         LowercaseCapital             capitalG             NaN  2880
# 3          Sequoia Capital     General Atlantic             NaN  3653
# 4       Blackbird Ventures      Matrix Partners             NaN  1434
#
#    Daily Value ($M)
# 0         81.871345
# 1         30.412371
# 2         32.986111
# 3         12.482891
# 4         27.894003

# %%
sns.scatterplot(data=unicorn, x = 'Age', y = 'Daily Value ($M)', hue='Industry', size='Valuation ($B)', palette = 'Spectral')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Daily Value ($M)'>

# %% [markdown]
# Interesting to see they mostly follow a set line, but there are few outliers. The most valuable unicorns don't seem to follow this trend at all.

# %%
unicorn.sort_values(by='Daily Value ($M)', ascending = False).tail(10) #top 10 biggest risers - and likely biggest intial investments
# Out:
#                      Company  Valuation ($B) Date Joined        Country  \
# 713                 Lamabang            1.00  2015-03-06          China
# 712                   BeiBei            1.00  2015-01-22          China
# 711             Red Ventures            1.00  2015-01-07  United States
# 710         LinkSure Network            1.00  2015-01-01          China
# 709                   InMobi            1.00  2014-12-02          India
# 660                  TangoMe            1.10  2014-03-20  United States
# 708  TechStyle Fashion Group            1.00  2014-08-29  United States
# 707                 Snapdeal            1.00  2014-05-21          India
# 706                  Lookout            1.00  2013-10-10  United States
# 557                   Veepee            1.38  2007-07-20         France
#
#                       City                         Industry  \
# 713               Shenzhen  E-commerce & direct-to-consumer
# 712               Hangzhou  E-commerce & direct-to-consumer
# 711              Fort Mill                            Other
# 710               Shanghai      Mobile & telecommunications
# 709              Bengaluru      Mobile & telecommunications
# 660          Mountain View      Mobile & telecommunications
# 708             El Segundo  E-commerce & direct-to-consumer
# 707              New Delhi  E-commerce & direct-to-consumer
# 706          San Francisco                    Cybersecurity
# 557  La Plaine Saint-Denis  E-commerce & direct-to-consumer
#
#                            Investor 1                      Investor 2  \
# 713                        5Y Capital           Matrix Partners China
# 712                    Banyan Capital             New Horizon Capital
# 711              Silver Lake Partners                General Atlantic
# 710        Haitong Kaiyuan Investment  Northern Light Venture Capital
# 709  Kleiner Perkins Caufield & Byers                  Softbank Corp.
# 660             Draper Fisher Jurtson               Qualcomm Ventures
# 708                   Matrix Partners                Passport Capital
# 707                     SoftBankGroup                       Blackrock
# 706                    Accel Partners               Greylock Partners
# 557                   Summit Partners                   Qatar Holding
#
#                Investor 3 Investor 4   Age  Daily Value ($M)
# 713                  K2VC        NaN  2473          0.404367
# 712  IDG Capital Partners        NaN  2516          0.397456
# 711                   NaN        NaN  2531          0.395101
# 710                   NaN        NaN  2537          0.394166
# 709     Sherpalo Ventures        NaN  2567          0.389560
# 660         Alibaba Group        NaN  2824          0.389518
# 708          Rho Ventures        NaN  2662          0.375657
# 707         Alibaba Group        NaN  2762          0.362056
# 706     Lowercase Capital        NaN  2985          0.335008
# 557                   NaN        NaN  5259          0.262407

# %% [markdown]
# Let's create a column to categorize the amount of increased value per day.

# %%
bins = [0, 5, 101, 500]
group_names = ['walk','trot','gallop'] #sticking with the unicorn theme
unicorn['Speed'] = pd.cut(unicorn['Daily Value ($M)'], bins, labels=group_names)

# %%
unicorn.head()
# Out:
#      Company  Valuation ($B) Date Joined        Country           City  \
# 0  Bytedance           140.0  2017-04-07          China        Beijing
# 1     SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2     Stripe            95.0  2014-01-23  United States  San Francisco
# 3     Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4      Canva            40.0  2018-01-08      Australia    Surry Hills
#
#                        Industry                      Investor 1  \
# 0       Artificial intelligence           Sequoia Capital China
# 1                         Other                   Founders Fund
# 2                       Fintech                 Khosla Ventures
# 3                       Fintech  Institutional Venture Partners
# 4  Internet software & services           Sequoia Capital China
#
#                 Investor 2           Investor 3      Investor 4   Age  \
# 0     SIG Asia Investments           Sina Weibo  Softbank Group  1710
# 1  Draper Fisher Jurvetson  Rothenberg Ventures             NaN  3298
# 2         LowercaseCapital             capitalG             NaN  2880
# 3          Sequoia Capital     General Atlantic             NaN  3653
# 4       Blackbird Ventures      Matrix Partners             NaN  1434
#
#    Daily Value ($M) Speed
# 0         81.871345  trot
# 1         30.412371  trot
# 2         32.986111  trot
# 3         12.482891  trot
# 4         27.894003  trot

# %%
sns.scatterplot(data=unicorn, x = 'Age', y = 'Daily Value ($M)', hue='Speed', palette = 'Spectral')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Daily Value ($M)'>

# %% [markdown]
# Work in progress..
